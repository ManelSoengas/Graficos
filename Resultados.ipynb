# %% [markdown]
# <a href="https://colab.research.google.com/github/ManelSoengas/Graficos/blob/main/Resultados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine learning**
# ## **Task1**
# ---
# Random Forest y XGBoost: Estos algoritmos también tienen resultados sólidos en las métricas, y en algunos casos, superan a otros algoritmos. Son algoritmos de conjunto que suelen funcionar bien en una variedad de problemas y son robustos frente a datos ruidosos.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de los algoritmos y métricas
algoritmos = ['SVC', 'Random Forest', 'XGBoost', 'NB']
accuracy = [0.71, 0.682, 0.685, 0.684]
precision = [0.70, 0.706, 0.705, 0.748]
recall = [0.69, 0.669, 0.681, 0.595]
f1 = [0.69, 0.687, 0.693, 0.663]

# Ancho de las barras
bar_width = 0.2

# Posiciones en el eje x para cada grupo de métricas
index = np.arange(len(algoritmos))

# Crear subgráficos para cada métrica
fig, ax = plt.subplots()
bar1 = ax.bar(index - bar_width, accuracy, bar_width, label='Accuracy')
bar2 = ax.bar(index, precision, bar_width, label='Precision')
bar3 = ax.bar(index + bar_width, recall, bar_width, label='Recall')
bar4 = ax.bar(index + 2 * bar_width, f1, bar_width, label='F1')

# Etiquetas en el eje x
ax.set_xticks(index + bar_width)
ax.set_xticklabels(algoritmos)

# Etiquetas y título
ax.set_xlabel('Algoritmo')
ax.set_ylabel('Puntuación')
ax.set_title('PREPROCESADO_1.Task1')

# Ubicación de la leyenda fuera del gráfico
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de los algoritmos y métricas para PREPROCESADO 2.TASK1
algoritmos = ['SVC', 'Random Forest', 'XGBoost', 'NB']
accuracy = [0.71, 0.693, 0.689, 0.684]
precision = [0.70, 0.716, 0.709, 0.736]
recall = [0.69, 0.683, 0.684, 0.617]
f1 = [0.69, 0.699, 0.697, 0.671]

# Ancho de las barras
bar_width = 0.2

# Posiciones en el eje x para cada grupo de métricas
index = np.arange(len(algoritmos))

# Crear subgráficos para cada métrica
fig, ax = plt.subplots()
bar1 = ax.bar(index - bar_width, accuracy, bar_width, label='Accuracy')
bar2 = ax.bar(index, precision, bar_width, label='Precision')
bar3 = ax.bar(index + bar_width, recall, bar_width, label='Recall')
bar4 = ax.bar(index + 2 * bar_width, f1, bar_width, label='F1')

# Etiquetas en el eje x
ax.set_xticks(index + bar_width)
ax.set_xticklabels(algoritmos)

# Etiquetas y título
ax.set_xlabel('Algoritmo')
ax.set_ylabel('Puntuación')
ax.set_title('PREPROCESADO_2.Task1')

# Ubicación de la leyenda fuera del gráfico
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Machine learning**
# ## **Task2**
#
#
# ---
# Si valoramos la precisión en general en la clasificación multiclase, SVC podría ser una opción sólida. Sin embargo, RF o XGb presentan un equilibrio entre precisión y recall,podrían ser opciones adecuadas.
#
# **SVC (Support Vector Classifier):**
#
# Ventajas: Tiene una alta precisión y F1-score, lo que sugiere que tiene un buen rendimiento general en la tarea de clasificación multiclase.
# Desventajas: El recall es relativamente bajo en comparación con otras métricas, lo que podría indicar que puede haber una cantidad significativa de falsos negativos.
#
# **Random Forest:**
#
# Ventajas: Ofrece una buena precisión y F1-score. También tiene un recall razonable. Random Forest es robusto y generalmente funciona bien en una variedad de conjuntos de datos.
# Desventajas: La precisión podría ser ligeramente más baja que la del SVC.
#
# **XGBoost:**
#
# Ventajas: Tiene una precisión y F1-score competitivas. El recall es razonable. XGBoost es conocido por su capacidad de manejar datos desequilibrados y es ampliamente utilizado en competiciones de aprendizaje automático.
# Desventajas: La precisión podría ser ligeramente más baja que la del SVC.

# %%
# Datos de los algoritmos y métricas
algoritmos = ['SVC', 'Random Forest', 'XGBoost', 'NB']
accuracy = [0.59, 0.59, 0.60, 0.52]
precision = [0.56, 0.62, 0.58, 0.57]
recall = [0.42, 0.39, 0.42, 0.26]
f1 = [0.47, 0.45, 0.47, 0.27]

# Ancho de las barras
bar_width = 0.2

# Posiciones en el eje x para cada grupo de métricas
index = np.arange(len(algoritmos))

# Crear subgráficos para cada métrica
fig, ax = plt.subplots()
bar1 = ax.bar(index - bar_width, accuracy, bar_width, label='Accuracy')
bar2 = ax.bar(index, precision, bar_width, label='Precision')
bar3 = ax.bar(index + bar_width, recall, bar_width, label='Recall')
bar4 = ax.bar(index + 2 * bar_width, f1, bar_width, label='F1')

# Etiquetas en el eje x
ax.set_xticks(index + bar_width)
ax.set_xticklabels(algoritmos)

# Etiquetas y título
ax.set_xlabel('Algoritmo')
ax.set_ylabel('Puntuación')
ax.set_title('Comparación de Métricas por Algoritmo')

# Ubicación de la leyenda fuera del gráfico
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Deep learning**
# ## **Task1_BERT**
#
#
# ---
# **Prueba_1**
#
# Configuración común : Training learning rate = 1e-5, batch size = 16, dropout=0.5. La diferencia se encuentra en la adición de la capa de normalización.
#
# Hay un equilibrio entre precisión y recall en ambas categorías, ambas configuraciones tienen puntajes de F1 similares, por lo que podrían ser opciones viables.

# %%
import matplotlib.pyplot as plt

# Configuración de los datos
categorias = ['BERT sin BatchNorm', 'BERT con BatchNorm']
sexist_accuracy = [0.68, 0.74]
sexist_recall = [0.75, 0.66]
sexist_f1 = [0.71, 0.70]

non_sexist_accuracy = [0.75, 0.72]
non_sexist_recall = [0.68, 0.79]
non_sexist_f1 = [0.71, 0.75]

# Ancho de las barras
bar_width = 0.2

# Posiciones en el eje x para cada grupo de métricas
index = range(len(categorias))

# Crear subgráficos para cada métrica (Accuracy, Recall, F1) para el género "sexist"
plt.figure(figsize=(10, 6))
plt.bar(index, sexist_accuracy, bar_width, label='Accuracy', alpha=0.7)
plt.bar([i + bar_width for i in index], sexist_recall, bar_width, label='Recall', alpha=0.7)
plt.bar([i + 2 * bar_width for i in index], sexist_f1, bar_width, label='F1', alpha=0.7)

# Etiquetas en el eje x
plt.xlabel('Configuración del Modelo')
plt.ylabel('Puntuación')
plt.title('Métricas de Rendimiento para el género "sexist"')
plt.xticks([i + bar_width for i in index], categorias)
plt.legend()

# Mostrar el gráfico
plt.show()

# Crear subgráficos para cada métrica (Accuracy, Recall, F1) para el género "non-sexist"
plt.figure(figsize=(10, 6))
plt.bar(index, non_sexist_accuracy, bar_width, label='Accuracy', alpha=0.7)
plt.bar([i + bar_width for i in index], non_sexist_recall, bar_width, label='Recall', alpha=0.7)
plt.bar([i + 2 * bar_width for i in index], non_sexist_f1, bar_width, label='F1', alpha=0.7)

# Etiquetas en el eje x
plt.xlabel('Configuración del Modelo')
plt.ylabel('Puntuación')
plt.title('Métricas de Rendimiento para el género "non-sexist"')
plt.xticks([i + bar_width for i in index], categorias)
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Prueba_2:**
#
# Separamos por Idioma, español y se utilizan modelos BERT y BETO.
#
# Si la detección de casos positivos es crítica y se puede tolerar una ligera disminución en la precisión, la configuración BERT + BatchNorm + Capa Densa podría ser la elección adecuada. También hay un buen equilibrio entre precisión y recall, BERT + BatchNorm es una opción sólida

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración de los datos
configuraciones = [
    "BERT",
    "BERT + BatchNorm",
    "BERT + BatchNorm + Capa Densa",
]

sexist_accuracy = [0.72, 0.72, 0.71]
sexist_recall = [0.67, 0.76, 0.80]
sexist_f1 = [0.69, 0.74, 0.75]

non_sexist_accuracy = [0.72, 0.76, 0.79]
non_sexist_recall = [0.76, 0.73, 0.70]
non_sexist_f1 = [0.74, 0.75, 0.74]

# Colores distintivos para cada configuración
colors = ['b', 'g', 'r']

# Posiciones en el eje x para cada configuración
index = np.arange(len(configuraciones))

# Crear gráficos de líneas para Accuracy, Recall y F1 para la categoría "sexist"
plt.figure(figsize=(12, 6))
plt.plot(index, sexist_accuracy, marker='o', label='Accuracy - Sexist', color='b')
plt.plot(index, sexist_recall, marker='o', label='Recall - Sexist', color='g')
plt.plot(index, sexist_f1, marker='o', label='F1 - Sexist', color='r')

# Crear gráficos de líneas para Accuracy, Recall y F1 para la categoría "non-sexist"
plt.plot(index, non_sexist_accuracy, marker='o', linestyle='--', label='Accuracy - Non-Sexist', color='b')
plt.plot(index, non_sexist_recall, marker='o', linestyle='--', label='Recall - Non-Sexist', color='g')
plt.plot(index, non_sexist_f1, marker='o', linestyle='--', label='F1 - Non-Sexist', color='r')

# Etiquetas en el eje x
plt.xlabel('Configuración del Modelo')
plt.ylabel('Puntuación')
plt.title('Comparación de Métricas de Rendimiento para Diferentes Configuraciones de Modelos')

# Personalizar las etiquetas del eje x con los nombres de las configuraciones
plt.xticks(index, configuraciones)

# Colocar la leyenda fuera del gráfico
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# **Prueba_3**
#
# Separamos por Idioma, inglés y se utiliza modelo BERT.
# Si la detección precisa de casos "sexist" es fundamental y se acepta aceptar una ligera disminución en la precisión general, la configuración BERT + BatchNorm + Capa Densa podría ser la elección. Sin embargo, también existe un equilibrio sólido entre precisión y recall, BERT + BatchNorm es una opción sólida.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración de los datos
configuraciones = [
    "BERT",
    "BERT + BatchNorm",
    "BERT + BatchNorm + Capa Densa",
]

sexist_accuracy = [0.74, 0.74, 0.73]
sexist_recall = [0.69, 0.70, 0.82]
sexist_f1 = [0.71, 0.76, 0.77]

non_sexist_accuracy = [0.74, 0.78, 0.82]
non_sexist_recall = [0.78, 0.69, 0.67]
non_sexist_f1 = [0.76, 0.77, 0.777]

# Colores distintivos para cada configuración
colors = ['b', 'g', 'r']

# Posiciones en el eje x para cada configuración
index = np.arange(len(configuraciones))

# Crear gráficos de líneas para Accuracy, Recall y F1 para la categoría "sexist"
plt.figure(figsize=(12, 6))
plt.plot(index, sexist_accuracy, marker='o', label='Accuracy - Sexist', color='b')
plt.plot(index, sexist_recall, marker='o', label='Recall - Sexist', color='g')
plt.plot(index, sexist_f1, marker='o', label='F1 - Sexist', color='r')

# Crear gráficos de líneas para Accuracy, Recall y F1 para la categoría "non-sexist"
plt.plot(index, non_sexist_accuracy, marker='o', linestyle='--', label='Accuracy - Non-Sexist', color='b')
plt.plot(index, non_sexist_recall, marker='o', linestyle='--', label='Recall - Non-Sexist', color='g')
plt.plot(index, non_sexist_f1, marker='o', linestyle='--', label='F1 - Non-Sexist', color='r')

# Etiquetas en el eje x
plt.xlabel('Configuración del Modelo')
plt.ylabel('Puntuación')
plt.title('Comparación de Métricas de Rendimiento para Diferentes Configuraciones de Modelos')

# Personalizar las etiquetas del eje x con los nombres de las configuraciones
plt.xticks(index, configuraciones)

# Colocar la leyenda fuera del gráfico
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# **Prueba_4 :**
#
# Sea aplican técnicas de aumeto de datos, por sínónimos y swapping.
#
# la configuración BERT + BatchNorm muestra un rendimiento general sólido, con un F1-score promedio de 0.725 y un equilibrio razonable entre precisión y recall en ambas categorías. Por lo tanto, podrías considerar esta configuración como la más robusta en términos generales para tu tarea de clasificación binaria.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración de los datos
configuraciones = [
    "BERT(sinónimos)",
    "BERT + BatchNorm(swapping)",
    "BERT + BatchNorm + Capas Densas(swapping)",
]

sexist_accuracy = [0.65, 0.70, 0.70]
sexist_recall = [0.80, 0.75, 0.76]
sexist_f1 = [0.72, 0.72, 0.73]

non_sexist_accuracy = [0.77, 0.76, 0.76]
non_sexist_recall = [0.60, 0.71, 0.70]
non_sexist_f1 = [0.67, 0.73, 0.73]

# Colores distintivos para cada configuración
colors = ['b', 'g', 'r']

# Posiciones en el eje x para cada configuración
index = np.arange(len(configuraciones))

# Crear gráficos de líneas para Accuracy, Recall y F1 para la categoría "sexist"
plt.figure(figsize=(12, 6))
plt.plot(index, sexist_accuracy, marker='o', label='Accuracy - Sexist', color='b')
plt.plot(index, sexist_recall, marker='o', label='Recall - Sexist', color='g')
plt.plot(index, sexist_f1, marker='o', label='F1 - Sexist', color='r')

# Crear gráficos de líneas para Accuracy, Recall y F1 para la categoría "non-sexist"
plt.plot(index, non_sexist_accuracy, marker='o', linestyle='--', label='Accuracy - Non-Sexist', color='b')
plt.plot(index, non_sexist_recall, marker='o', linestyle='--', label='Recall - Non-Sexist', color='g')
plt.plot(index, non_sexist_f1, marker='o', linestyle='--', label='F1 - Non-Sexist', color='r')

# Etiquetas en el eje x
plt.xlabel('Configuración del Modelo')
plt.ylabel('Puntuación')
plt.title('Comparación de Métricas de Rendimiento para Diferentes Configuraciones de Modelos')

# Personalizar las etiquetas del eje x con los nombres de las configuraciones
plt.xticks(index, configuraciones, rotation=15)  # Rotar las etiquetas para mayor claridad

# Colocar la leyenda fuera del gráfico
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# #**Deep learning**
# ##**Task1_RoBERTa**
#
#
# ---
# Aplicando separación de idiomas en y es conjuntamente con ampliación de datos mediante técnica swapping se consigue lograr
#
# Accuracy on test dataset: 0.7531702898550725
# F1 score on test dataset: 0.7524169441792469

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configuración de los datos
configuraciones = [
    "RoBERTa Sin Preprocesamiento",
    "RoBERTa Con Preprocesamiento",
]

sexist_accuracy = [0.77, 0.70]
sexist_recall = [0.70, 0.76]
sexist_f1 = [0.74, 0.73]

non_sexist_accuracy = [0.75, 0.76]
non_sexist_recall = [0.81, 0.70]
non_sexist_f1 = [0.78, 0.73]

# Colores distintivos para cada configuración
colors = ['b', 'g', 'r']

# Posiciones en el eje x para cada configuración
index = np.arange(len(configuraciones))

# Ancho de las barras
bar_width = 0.2

# Crear gráficos de barras para Accuracy, Recall y F1 para la categoría "sexist"
plt.figure(figsize=(12, 6))
plt.bar(index, sexist_accuracy, bar_width, label='Accuracy - Sexist', color='b', alpha=0.8)
plt.bar(index + bar_width, sexist_recall, bar_width, label='Recall - Sexist', color='g', alpha=0.8)
plt.bar(index + 2 * bar_width, sexist_f1, bar_width, label='F1 - Sexist', color='r', alpha=0.8)

# Crear gráficos de barras para Accuracy, Recall y F1 para la categoría "non-sexist"
plt.bar(index, non_sexist_accuracy, bar_width, label='Accuracy - Non-Sexist', color='b', alpha=0.5, hatch='//')
plt.bar(index + bar_width, non_sexist_recall, bar_width, label='Recall - Non-Sexist', color='g', alpha=0.5, hatch='//')
plt.bar(index + 2 * bar_width, non_sexist_f1, bar_width, label='F1 - Non-Sexist', color='r', alpha=0.5, hatch='//')

# Etiquetas en el eje x
plt.xlabel('Configuración del Modelo')
plt.ylabel('Puntuación')
plt.title('Comparación de Métricas de Rendimiento para Configuraciones de RoBERTa')

# Personalizar las etiquetas del eje x con los nombres de las configuraciones
plt.xticks(index + bar_width, configuraciones, rotation=15)

# Colocar la leyenda fuera del gráfico
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# #**Deep learning**
# ##**Task2_BERT_&_RoBERTa**
#
# ---
#
# **Para los dos idiomas incluidos:**
#
# Basándome en estos resultados, la "Configuración 2" de BERT muestra un rendimiento generalmente mejor en términos de precisión y puntuación F1 en comparación con RoBERTa. Por lo tanto, en esta situación, elegiría BERT, específicamente la "Configuración 2", como la opción preferida.
#
#
# ---
# **Para el idioma Inglés:**
#
# Basándome en estos resultados, la "Configuración 1" de RoBERTa muestra un rendimiento generalmente mejor en términos de precisión, recall y puntuación F1 en comparación con BERT. Por lo tanto, en esta situación, elegiría RoBERTa, específicamente la "Configuración 1", como la opción preferida. Ofrece un rendimiento más sólido en múltiples métricas clave.
#
#
# ---
#
# **Para el idioma Español:**
#
# En general, BETO tiene un rendimiento sólido en las tres métricas clave (precisión, recall y puntuación F1) en ambas configuraciones. Por lo tanto, basándome en los resultados proporcionados, elegiría BETO como la opción preferida.
#
# En general los modelos obtienen mejor resultado separando por idioma y utilizando modelos especificos para el idioma y tarea,

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir los nombres de las configuraciones
configuraciones = ['Config 1', 'Config 2']

# Definir las métricas y sus valores correspondientes
exactitud = [0.63, 0.64]
recall = [0.62, 0.63]
f1_score = [0.62, 0.63]

# Crear una figura con dos ejes y
fig, ax1 = plt.subplots(figsize=(10, 6))

# Configurar el primer eje y para Exactitud y Puntuación F1
ax1.set_xlabel('Configuraciones. Ambos idiomas incluidos')
ax1.set_ylabel('Exactitud y Puntuación F1', color='tab:blue')
ax1.plot(configuraciones, exactitud, marker='o', label='Exactitud', color='tab:blue')
ax1.plot(configuraciones, f1_score, marker='o', label='Puntuación F1', linestyle='--', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Crear un segundo eje y para Recall
ax2 = ax1.twinx()
ax2.set_ylabel('Recall', color='tab:red')
ax2.plot(configuraciones, recall, marker='o', label='Recall', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Agregar título
plt.title('BERT. Configuración 1 y Configuración 2')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir los nombres de las configuraciones
configuraciones_roberta = ['Config 1', 'Config 2']

# Definir las métricas y sus valores correspondientes para RoBERTa
exactitud_roberta = [0.610, 0.619]
recall_roberta = [0.660, 0.642]
f1_score_roberta = [0.580, 0.590]

# Crear una figura con dos ejes y
fig, ax1 = plt.subplots(figsize=(10, 6))

# Configurar el primer eje y para Exactitud y Puntuación F1 (RoBERTa)
ax1.set_xlabel('Configuraciones (Ambos idiomas incluidos) - RoBERTa')
ax1.set_ylabel('Exactitud y Puntuación F1', color='tab:blue')
ax1.plot(configuraciones_roberta, exactitud_roberta, marker='o', label='Exactitud', color='tab:blue')
ax1.plot(configuraciones_roberta, f1_score_roberta, marker='o', label='Puntuación F1', linestyle='--', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Crear un segundo eje y para Recall (RoBERTa)
ax2 = ax1.twinx()
ax2.set_ylabel('Recall', color='tab:red')
ax2.plot(configuraciones_roberta, recall_roberta, marker='o', label='Recall', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Agregar título
plt.title('RoBERTa. Configuración 1 y Configuración 2')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # **BERT_&_RoBERTa.Task2**
#
#
# ---
#
#
# Para el idioma Inglés

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir las configuraciones
configuraciones = ['Config 1', 'Config 2']

# Definir los valores de precisión, recall y puntuación F1
accuracy = [0.64, 0.63]
recall = [0.63, 0.63]
f1_score = [0.63, 0.62]

# Crear una figura con dos ejes y
fig, ax1 = plt.subplots(figsize=(10, 6))

# Configurar el primer eje y para Accuracy y F1-Score
ax1.set_xlabel('Configuraciones_BERT. Idioma Inglés')
ax1.set_ylabel('Accuracy y F1-Score', color='tab:blue')
ax1.plot(configuraciones, accuracy, marker='o', label='Accuracy', color='tab:blue')
ax1.plot(configuraciones, f1_score, marker='o', label='F1-Score', linestyle='--', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Crear un segundo eje y para Recall
ax2 = ax1.twinx()
ax2.set_ylabel('Recall', color='tab:red')
ax2.plot(configuraciones, recall, marker='o', label='Recall', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Agregar título
plt.title('Resultados de BERT en Configuración 1 y Configuración 2')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir las configuraciones
configuraciones_roberta = ['Config 1', 'Config 2']

# Definir los valores de precisión, recall y puntuación F1 para RoBERTa
accuracy_roberta = [0.65, 0.62]
recall_roberta = [0.65, 0.62]
f1_score_roberta = [0.64, 0.61]

# Crear una figura con dos ejes y
fig, ax1 = plt.subplots(figsize=(10, 6))

# Configurar el primer eje y para Accuracy y F1-Score (RoBERTa)
ax1.set_xlabel('Configuraciones_RoBERTa. Idioma Inglés.')
ax1.set_ylabel('Accuracy y F1-Score', color='tab:blue')
ax1.plot(configuraciones_roberta, accuracy_roberta, marker='o', label='Accuracy', color='tab:blue')
ax1.plot(configuraciones_roberta, f1_score_roberta, marker='o', label='F1-Score', linestyle='--', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Crear un segundo eje y para Recall (RoBERTa)
ax2 = ax1.twinx()
ax2.set_ylabel('Recall', color='tab:red')
ax2.plot(configuraciones_roberta, recall_roberta, marker='o', label='Recall', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Agregar título
plt.title('Resultados de RoBERTa en Configuración 1 y Configuración 2')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# **BERT_&_RoBERTa.Task2**
#
# ---
#
#
# Para el idioma Español

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir las configuraciones
configuraciones_beto = ['Config 1', 'Config 2']

# Definir los valores de precisión, recall y puntuación F1 para BETO
accuracy_beto = [0.690, 0.660]
recall_beto = [0.700, 0.660]
f1_score_beto = [0.690, 0.650]

# Crear una figura con dos ejes y
fig, ax1 = plt.subplots(figsize=(10, 6))

# Configurar el primer eje y para Accuracy y F1-Score (BETO)
ax1.set_xlabel('Configuraciones_BETO. Español')
ax1.set_ylabel('Accuracy y F1-Score', color='tab:blue')
ax1.plot(configuraciones_beto, accuracy_beto, marker='o', label='Accuracy', color='tab:blue')
ax1.plot(configuraciones_beto, f1_score_beto, marker='o', label='F1-Score', linestyle='--', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Crear un segundo eje y para Recall (BETO)
ax2 = ax1.twinx()
ax2.set_ylabel('Recall', color='tab:red')
ax2.plot(configuraciones_beto, recall_beto, marker='o', label='Recall', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Agregar título
plt.title('Resultados de BETO en Configuración 1 y Configuración 2')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir las configuraciones
configuraciones_robertuito = ['Config 1', 'Config 2']

# Definir los valores de precisión, recall y puntuación F1 para RoBERTuito
accuracy_robertuito = [0.681, 0.682]
recall_robertuito = [0.656, 0.660]
f1_score_robertuito = [0.661, 0.672]

# Crear una figura con dos ejes y
fig, ax1 = plt.subplots(figsize=(10, 6))

# Configurar el primer eje y para Accuracy y F1-Score (RoBERTuito)
ax1.set_xlabel('Configuraciones_RoBERTuito. Español')
ax1.set_ylabel('Accuracy y F1-Score', color='tab:blue')
ax1.plot(configuraciones_robertuito, accuracy_robertuito, marker='o', label='Accuracy', color='tab:blue')
ax1.plot(configuraciones_robertuito, f1_score_robertuito, marker='o', label='F1-Score', linestyle='--', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

# Crear un segundo eje y para Recall (RoBERTuito)
ax2 = ax1.twinx()
ax2.set_ylabel('Recall', color='tab:red')
ax2.plot(configuraciones_robertuito, recall_robertuito, marker='o', label='Recall', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.legend(loc='upper right')

# Agregar título
plt.title('Resultados de RoBERTuito en Configuración 1 y Configuración 2')

# Mostrar el gráfico
plt.tight_layout()
plt.show()
